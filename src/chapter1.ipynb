# %%
import nltk
import matplotlib.pyplot as plt 
import numpy as np

# %%
nltk.download('book')
from nltk.book import *
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /home/vscode/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /home/vscode/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# ...

# %% [markdown]
# # 1.8 Exercises

# %% [markdown]
# 1. Try using the Python interpreter as a calculator, and typing expressions like 12 / (4 + 1).

# %%
print(12 / (4 + 1))
# Out:
# 2.4

# %% [markdown]
# 2. Given an alphabet of 26 letters, there are 26 to the power 10, or 26 ** 10, ten-letter strings we can form. That works out to 141167095653376. How many hundred-letter strings are possible?

# %%
26 ** 100
# Out:
# 3142930641582938830174357788501626427282669988762475256374173175398995908420104023465432599069702289330964075081611719197835869803511992549376

# %% [markdown]
# 3. The Python multiplication operation can be applied to lists. What happens when you type \['Monty', 'Python'\] * 20, or 3 * sent1?

# %%
print(['Monty', 'Python'] * 20)
# sent1 = ['Call', 'me', 'Ishmael', '.']
print(3 * sent1)
# Out:
# ['Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python', 'Monty', 'Python']
# ['Call', 'me', 'Ishmael', '.', 'Call', 'me', 'Ishmael', '.', 'Call', 'me', 'Ishmael', '.']

# %% [markdown]
# 4. Review 1 on computing with language. How many words are there in text2? How many distinct words are there?

# %%
print('words count: {}'.format(len(text2)))
print('distinct words: {}'.format(len(set(text2))))
# Out:
# words count: 141576
# distinct words: 6833

# %% [markdown]
# 5. Compare the lexical diversity scores for humor and romance fiction in 1.1. Which genre is more lexically diverse?

# %%
from nltk.corpus import brown

def lexical_diversity(text):
    return len(set(text)) / len(text)

print('humor: {}'.format(lexical_diversity(brown.words(categories='humor'))))
print('romance: {}'.format(lexical_diversity(brown.words(categories='romance'))))
# Out:
# humor: 0.23125144042406084
# romance: 0.12070492131044529

# %%
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
print(lexical_diversity(brown.words(categories='humor')))
print(lexical_diversity(brown.words(categories='romance')))
# Out:
# 0.23125144042406084
# 0.12070492131044529

# %% [markdown]
# 6.

# %%
text2.tokens
# Out:
# ['[',
#  'Sense',
#  'and',
#  'Sensibility',
#  'by',
#  'Jane',
#  'Austen',
#  '1811',
#  ']',
#  'CHAPTER',
#  '1',
#  'The',
#  'family',
#  'of',
#  'Dashwood',
#  'had',
#  'long',
#  'been',
#  'settled',
#  'in',
#  'Sussex',
#  '.',
#  'Their',
#  'estate',
#  'was',
#  'large',
#  ',',
#  'and',
#  'their',
#  'residence',
#  'was',
#  'at',
#  'Norland',
#  'Park',
#  ',',
#  'in',
#  'the',
#  'centre',
#  'of',
#  'their',
#  'property',
#  ',',
#  'where',
#  ',',
#  'for',
#  'many',
#  'generations',
#  ',',
#  'they',
#  'had',
#  'lived',
#  'in',
#  'so',
#  'respectable',
#  'a',
#  'manner',
#  'as',
#  'to',
#  'engage',
#  'the',
#  'general',
#  'good',
#  'opinion',
#  'of',
#  'their',
#  'surrounding',
#  'acquaintance',
#  '.',
#  'The',
#  'late',
#  'owner',
#  'of',
#  'this',
#  'estate',
#  'was',
#  'a',
#  'single',
#  'man',
#  ',',
#  'who',
#  'lived',
#  'to',
#  'a',
#  'very',
#  'advanced',
#  'age',
#  ',',
#  'and',
#  'who',
#  'for',
# ...

# %%
for x in dir(text2):
    print(x, ':', type(eval("text2."+x)))
# Out:
# _CONTEXT_RE : <class 're.Pattern'>
# _COPY_TOKENS : <class 'bool'>
# __class__ : <class 'type'>
# __delattr__ : <class 'method-wrapper'>
# __dict__ : <class 'dict'>
# __dir__ : <class 'builtin_function_or_method'>
# __doc__ : <class 'str'>
# __eq__ : <class 'method-wrapper'>
# __format__ : <class 'builtin_function_or_method'>
# __ge__ : <class 'method-wrapper'>
# __getattribute__ : <class 'method-wrapper'>
# __getitem__ : <class 'method'>
# __gt__ : <class 'method-wrapper'>
# __hash__ : <class 'method-wrapper'>
# __init__ : <class 'method'>
# __init_subclass__ : <class 'builtin_function_or_method'>
# __le__ : <class 'method-wrapper'>
# __len__ : <class 'method'>
# __lt__ : <class 'method-wrapper'>
# __module__ : <class 'str'>
# __ne__ : <class 'method-wrapper'>
# __new__ : <class 'builtin_function_or_method'>
# __reduce__ : <class 'builtin_function_or_method'>
# __reduce_ex__ : <class 'builtin_function_or_method'>
# __repr__ : <class 'method'>
# ...

# %%
protagonists = ['Elinor', 'Marianne', 'Edward', 'Willoughby']
# Sense and Sensibility: text2
text2.dispersion_plot(protagonists)
plt.savefig('sence_dispersion.png', format='png', dpi=600)

# %% [markdown]
# 7

# %%
text5.collocation_list()
# Out:
# [('wanna', 'chat'),
#  ('PART', 'JOIN'),
#  ('MODE', '#14-19teens'),
#  ('JOIN', 'PART'),
#  ('PART', 'PART'),
#  ('cute.-ass', 'MP3'),
#  ('MP3', 'player'),
#  ('JOIN', 'JOIN'),
#  ('times', '.. .'),
#  ('ACTION', 'watches'),
#  ('guys', 'wanna'),
#  ('song', 'lasts'),
#  ('last', 'night'),
#  ('ACTION', 'sits'),
#  ('-...)...-', 'S.M.R.'),
#  ('Lime', 'Player'),
#  ('Player', '12%'),
#  ('dont', 'know'),
#  ('lez', 'gurls'),
#  ('long', 'time')]

# %%
[i for i in range(len(sent3)) if sent3[i] == 'the']
# Out:
# [1, 5, 8]

# %%
fdist = FreqDist([word for word in text5 if word.isalpha() and len(word) == 4])

# %%
print(fdist.most_common(20))
# Out:
# [('JOIN', 1021), ('PART', 1016), ('that', 274), ('what', 183), ('here', 181), ('have', 164), ('like', 156), ('with', 152), ('chat', 142), ('your', 137), ('good', 130), ('just', 125), ('lmao', 107), ('know', 103), ('room', 98), ('from', 92), ('this', 86), ('well', 81), ('back', 78), ('hiya', 78)]

# %%
# Out:
# 1038
